# %%
import seaborn as sns
import pandas as pd
import numpy as np

# from https://www.youtube.com/watch?v=3Ggc4aCI2k4, but i'm pretty sure this is now outdated oops

sns.set(style="white")

random_state = np.random.RandomState(10)

mean = [2, 2]
cov = [(1, .5), (.5, 1)]

x1, x2 = random_state.multivariate_normal(mean, cov, 500).T

x1 = pd.Series(x1, name="Example_X")
x2 = pd.Series(x2, name="Example_Y")

# uncomment the following to generate plot
# example_plot = sns.jointplot(x2, kind="kde", space=0, color="blue")

# %%
# import seaborn as sns
# import pandas as pd
# import numpy as np

# sns.kdeplot(
#     data=df, x="x1", y="x2",
#     fill=True, thresh=0, levels=100, cmap="mako",
# )

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(200)
res = sns.kdeplot(data,color='green',fill=True)
plt.show()
